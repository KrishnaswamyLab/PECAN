# %%
import phate
from sklearn.decomposition import TruncatedSVD
import numpy as np
from scipy.sparse.linalg import eigs
from functions import moon_petals, make_diffusion
import matplotlib.pyplot as plt

# %%
X, _ = moon_petals(128, degree= 1.5 * np.pi)
P = make_diffusion(X)

# %%
for t in range(1,20):
    phate_op = phate.PHATE(t=t)
    data_phate = phate_op.fit_transform(X)
    plt.figure()
    plt.title(t)
    plt.scatter(data_phate[:, 0], data_phate[:, 1])
    plt.show()
# Out:
# Calculating PHATE...
#   Running PHATE on 121 observations and 2 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.13 seconds.
#   Calculated graph and diffusion operator in 0.14 seconds.
#   Calculating diffusion potential...
#   Calculating metric MDS...
#   Calculated metric MDS in 0.01 seconds.
# Calculated PHATE in 0.17 seconds.
# Calculating PHATE...
#   Running PHATE on 121 observations and 2 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.01 seconds.
#   Calculating diffusion potential...
#   Calculating metric MDS...
#   Calculated metric MDS in 0.01 seconds.
# Calculated PHATE in 0.03 seconds.
# Calculating PHATE...
#   Running PHATE on 121 observations and 2 variables.
#   Calculating graph and diffusion operator...
# ...

# %%
plt.figure()
plt.scatter(data_phate[:, 0], data_phate[:, 1])
plt.show()

# %%
phate_op.diff_potential.shape
# Out:
# (121, 121)

# %%
# Out:
# array([[ 0.        ,  0.0241177 ,  0.00962786, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.0241177 ,  0.        , -0.0083907 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.00962786,  0.0083907 ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.00696857,  0.00625789],
#        [ 0.        ,  0.        ,  0.        , ..., -0.00696857,
#          0.        ,  0.00863576],
#        [ 0.        ,  0.        ,  0.        , ..., -0.00625789,
#         -0.00863576,  0.        ]])
