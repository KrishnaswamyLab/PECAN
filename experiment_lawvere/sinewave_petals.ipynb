# %%
import numpy as np
import matplotlib.pyplot as plt
from functions import make_diffusion_d, sinewave_petals, visuallize_diffusion_map_subplot_correct, make_diffusion_box_d, make_diffusion_knn_d
from functions import plot_diffusions
s = 10

# %%
X, _ = sinewave_petals(length=10, A=2, B=1, C=1)
plt.scatter(X[:, 0], X[:, 1], s=s)

# %%
# Create a 4x5 grid of subplots
fig, axes = plt.subplots(4, 5, figsize=(20, 16))

epsilons = np.arange(1, 21) * 0.5
alpha = 5
t = 10
# Assuming petals is a function that you've defined to generate data
for i, epsilon in enumerate(epsilons):
    row = i // 5  # Integer division to get row index
    col = i % 5   # Remainder to get column index
    P, d = make_diffusion_d(X, alpha=10, epsilon=epsilon)
    visuallize_diffusion_map_subplot_correct(X, P, d, ax=axes[row, col], name='petals', epsilon=epsilon, alpha=alpha, t=t, s=s)
plt.tight_layout()
plt.show()

# %%
epsilons = np.arange(1, 11) * 0.5
for epsilon in epsilons:
    plot_diffusions(epsilon=epsilon, alpha=2, t=10, X=X, s=s)

# %%
# Create a 4x5 grid of subplots
fig, axes = plt.subplots(4, 5, figsize=(20, 16))
alphas = np.arange(1, 21)
epsilon = 6
# Assuming petals is a function that you've defined to generate data
for i, alpha in enumerate(alphas):
    row = i // 5  # Integer division to get row index
    col = i % 5   # Remainder to get column index
    P, d = make_diffusion_d(X, alpha=alpha, epsilon=epsilon)
    visuallize_diffusion_map_subplot_correct(X, P, d, ax=axes[row, col], name='petals', epsilon=epsilon, alpha=alpha, t=10, s=s)
plt.tight_layout()
plt.show()

# %%
epsilon = 6
alphas = np.arange(1, 11)
for alpha in alphas:
    plot_diffusions(epsilon=epsilon, alpha=alpha, t=10, X=X, s=s)
